# %%
import pandas as pd
import pickle
import json
import requests
from scipy import signal
from datetime import date,timedelta
import yaml
import copy
import numpy as np

import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
start = pd.to_datetime('2023-01-01')
eval_dates = [start + datetime.timedelta(days=7*j) for j in range(0,52)]

cases = pd.read_csv('/Users/elizabethmurphy/Downloads/covid19cases_test.csv',index_col=0)
cases = cases[cases['area'] =='San Diego']
cases = cases[(cases.index>='2020-06-01') & (cases.index<='2022-07-01')]
cases.index = pd.to_datetime(cases.index)

cases['cases'] = cases['cases'].rolling(window=7, center=True, min_periods=0).mean()
cases['positivity'] = cases['cases'].rolling(window=7, center=True, min_periods=0).mean()/cases['total_tests'].rolling(window=7, center=True, min_periods=0).mean()

ww_dict = {'Point Loma':['/Users/elizabethmurphy/Downloads/PointLoma_sewage_seqs.csv','/Users/elizabethmurphy/Downloads/PointLoma_sewage_qPCR.csv']}
for site, files in zip(ww_dict.keys(),ww_dict.values()):
    df = pd.read_csv(f'{files[0]}')

    df['Date'] = pd.to_datetime(df['Date'])
    df.columns = [dfc.split(' (')[0] for dfc in df.columns]
    df =df.set_index('Date')
    df = df[df.index>='2020-06-01']
    df = df[df.index<='2022-07-01']
    df = df.dropna(axis = 0, how = 'all')
    df = df.fillna(0)
    df = df/100.

    df = df.drop(columns=['Other'])
    df = df[df.columns[df.sum(axis=0) > 0.01]]

    cdf = pd.read_csv(f'{files[1]}')
    cdf['Sample_Date'] = pd.to_datetime(cdf['Sample_Date'])
    cdf =cdf.set_index('Sample_Date')
    sharedInds = np.sort(list(set(cdf.index) & set(df.index)))
    cdf = cdf.loc[sharedInds]
    df = df.loc[sharedInds]
    df = df[~df.index.duplicated(keep='last')]
    scaleddf = df.mul(cdf['Mean viral gene copies/L'],axis=0)

    cdf = cdf.resample('D').asfreq()
    cdf = cdf.rolling(window=7, center=True, min_periods=0).mean()


cdf = pd.concat([cdf,cases],axis=1)
cdf = cdf.dropna(how='any')

N = 30
F = 5
# first, let's learn the shedding kernel
X = np.array([cdf['Mean viral gene copies/L'].values[(j-F):(j+N-F)] for j in range(F,(cdf.shape[0]-N+F))])/cdf['Mean viral gene copies/L'].mean()
# add coeficient term
Y = cdf['cases'].values[F:(len(cdf['cases'])-N+F)]

import cvxpy as cp

# least squares problem
x = cp.Variable(N)
cost = cp.norm(X @ x - Y,2)
constraints = [x >= 0]
prob = cp.Problem(cp.Minimize(cost),constraints)
prob.solve(verbose=True)#,solver=cp.CLARABEL)

Y2 = cdf['positivity'].values[0:(len(cdf['positivity'])-N)]

# switch to logistic function
beta = cp.Variable(N,nonneg=True)#+1)
log_likelihood = cp.sum(
    cp.multiply(Y2, X @ beta) - cp.logistic(X @ beta)
)
# constraints = [beta >= 0.001, beta<=10]
prob2 = cp.Problem(cp.Maximize(log_likelihood))#,constraints)
prob2.solve(verbose=True)#,solver=cp.CLARABEL)


fig,ax = plt.subplots()
ax.plot(range(-F,len(x.value)-F),x.value) # just plotting the curve learned via the case counts for now. 
ax.set_xlabel('Date relative to detection')
ax.set_ylabel('Mean viral load copies/L')
# Out:
# /var/folders/s2/nry612l527j2xxdsq0_70h6m0000gn/T/ipykernel_30681/4025342802.py:29: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cdf['Sample_Date'] = pd.to_datetime(cdf['Sample_Date'])
# (CVXPY) Jul 08 12:04:47 PM: Your problem has 30 variables, 30 constraints, and 0 parameters.
# (CVXPY) Jul 08 12:04:47 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jul 08 12:04:47 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jul 08 12:04:47 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Jul 08 12:04:47 PM: Your problem is compiled with the CPP canonicalization backend.
# (CVXPY) Jul 08 12:04:47 PM: Compiling problem (target solver=CLARABEL).
# (CVXPY) Jul 08 12:04:47 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> CLARABEL
# (CVXPY) Jul 08 12:04:47 PM: Applying reduction Dcp2Cone
# (CVXPY) Jul 08 12:04:47 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jul 08 12:04:47 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Jul 08 12:04:47 PM: Applying reduction CLARABEL
# (CVXPY) Jul 08 12:04:47 PM: Finished problem compilation (took 1.098e-02 seconds).
# (CVXPY) Jul 08 12:04:47 PM: Invoking solver CLARABEL  to obtain a solution.
# ===============================================================================
#                                      CVXPY
#                                      v1.6.6
# ===============================================================================
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# -------------------------------------------------------------
#            Clarabel.rs v0.11.1  -  Clever Acronym
#
#                    (c) Paul Goulart
#                 University of Oxford, 2022
# -------------------------------------------------------------
#
# problem:
#   variables     = 31
#   constraints   = 233
#   nnz(P)        = 0
#   nnz(A)        = 6091
#   cones (total) = 2
#     : Nonnegative = 1,  numel = 30
#     : SecondOrder = 1,  numel = 203
#
# settings:
#   linear algebra: direct / qdldl, precision: 64 bit (1 thread)
#   max iter = 200, time limit = Inf,  max step = 0.990
#   tol_feas = 1.0e-8, tol_gap_abs = 1.0e-8, tol_gap_rel = 1.0e-8,
#   static reg : on, ϵ1 = 1.0e-8, ϵ2 = 4.9e-32
#   dynamic reg: on, ϵ = 1.0e-13, δ = 2.0e-7
#   iter refine: on, reltol = 1.0e-13, abstol = 1.0e-12,
#                max iter = 10, stop ratio = 5.0
#   equilibrate: on, min_scale = 1.0e-4, max_scale = 1.0e4
#                max iter = 10
#
# iter    pcost        dcost       gap       pres      dres      k/t        μ       step
# ---------------------------------------------------------------------------------------------
# (CVXPY) Jul 08 12:04:47 PM: Problem status: optimal
# (CVXPY) Jul 08 12:04:47 PM: Optimal value: 8.113e+03
# (CVXPY) Jul 08 12:04:47 PM: Compilation took 1.098e-02 seconds
# (CVXPY) Jul 08 12:04:47 PM: Solver (including time spent in interface) took 5.243e-03 seconds
# (CVXPY) Jul 08 12:04:47 PM: Your problem has 30 variables, 0 constraints, and 0 parameters.
# (CVXPY) Jul 08 12:04:47 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jul 08 12:04:47 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jul 08 12:04:47 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Jul 08 12:04:47 PM: Your problem is compiled with the CPP canonicalization backend.
# (CVXPY) Jul 08 12:04:47 PM: Compiling problem (target solver=CLARABEL).
# (CVXPY) Jul 08 12:04:47 PM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> CLARABEL
# (CVXPY) Jul 08 12:04:47 PM: Applying reduction FlipObjective
# (CVXPY) Jul 08 12:04:47 PM: Applying reduction Dcp2Cone
# (CVXPY) Jul 08 12:04:47 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jul 08 12:04:47 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Jul 08 12:04:47 PM: Applying reduction CLARABEL
# (CVXPY) Jul 08 12:04:47 PM: Finished problem compilation (took 7.279e-03 seconds).
# (CVXPY) Jul 08 12:04:47 PM: Invoking solver CLARABEL  to obtain a solution.
#   0  +0.0000e+00  -0.0000e+00  0.00e+00  8.17e-01  1.01e-02  1.00e+00  2.60e+04   ------
#   1  +6.3576e+03  +6.3842e+03  4.19e-03  1.98e-01  1.93e-04  2.67e+01  3.00e+03  8.86e-01
#   2  +6.8042e+03  +7.0396e+03  3.46e-02  1.45e-01  1.33e-04  2.35e+02  2.68e+03  2.39e-01
#   3  +7.5963e+03  +7.7996e+03  2.68e-02  3.10e-02  2.59e-05  2.03e+02  1.59e+03  7.80e-01
#   4  +7.4796e+03  +7.9045e+03  5.68e-02  5.00e-02  4.18e-05  4.25e+02  1.55e+03  1.64e-01
#   5  +7.5917e+03  +7.6848e+03  1.23e-02  1.45e-02  1.21e-05  9.31e+01  5.13e+02  7.38e-01
#   6  +7.8421e+03  +7.8894e+03  6.04e-03  4.71e-03  3.87e-06  4.74e+01  1.16e+02  8.34e-01
#   7  +7.9723e+03  +7.9882e+03  2.00e-03  1.82e-03  1.49e-06  1.60e+01  4.35e+01  7.00e-01
#   8  +8.0359e+03  +8.0523e+03  2.05e-03  1.46e-03  1.19e-06  1.65e+01  2.38e+01  5.79e-01
#   9  +8.0958e+03  +8.0979e+03  2.60e-04  2.82e-04  2.28e-07  2.11e+00  5.04e+00  8.40e-01
#  10  +8.1110e+03  +8.1112e+03  2.99e-05  3.86e-05  3.13e-08  2.43e-01  7.02e-01  8.63e-01
#  11  +8.1125e+03  +8.1125e+03  7.65e-07  1.10e-06  8.87e-10  6.20e-03  2.00e-02  9.72e-01
#  12  +8.1125e+03  +8.1125e+03  2.41e-08  3.42e-08  2.77e-11  1.96e-04  6.27e-04  9.70e-01
#  13  +8.1125e+03  +8.1125e+03  2.28e-09  2.84e-09  2.30e-12  1.85e-05  5.20e-05  9.36e-01
# ---------------------------------------------------------------------------------------------
# Terminated with status = Solved
# solve time = 3.310125ms
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# ===============================================================================
#                                      CVXPY
#                                      v1.6.6
# ===============================================================================
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# -------------------------------------------------------------
#            Clarabel.rs v0.11.1  -  Clever Acronym
#
#                    (c) Paul Goulart
#                 University of Oxford, 2022
# -------------------------------------------------------------
#
# problem:
#   variables     = 636
#   constraints   = 1444
#   nnz(P)        = 0
#   nnz(A)        = 7302
#   cones (total) = 405
#     : Nonnegative = 1,  numel = 232
#     : Exponential = 404,  numel = (3,3,3,3,...,3)
#
# settings:
#   linear algebra: direct / qdldl, precision: 64 bit (1 thread)
#   max iter = 200, time limit = Inf,  max step = 0.990
#   tol_feas = 1.0e-8, tol_gap_abs = 1.0e-8, tol_gap_rel = 1.0e-8,
#   static reg : on, ϵ1 = 1.0e-8, ϵ2 = 4.9e-32
#   dynamic reg: on, ϵ = 1.0e-13, δ = 2.0e-7
#   iter refine: on, reltol = 1.0e-13, abstol = 1.0e-12,
#                max iter = 10, stop ratio = 5.0
#   equilibrate: on, min_scale = 1.0e-4, max_scale = 1.0e4
#                max iter = 10
#
# iter    pcost        dcost       gap       pres      dres      k/t        μ       step
# ---------------------------------------------------------------------------------------------
# (CVXPY) Jul 08 12:04:47 PM: Problem status: optimal
# (CVXPY) Jul 08 12:04:47 PM: Optimal value: -1.400e+02
# (CVXPY) Jul 08 12:04:47 PM: Compilation took 7.279e-03 seconds
# (CVXPY) Jul 08 12:04:47 PM: Solver (including time spent in interface) took 1.089e-02 seconds
#   0  +0.0000e+00  -4.2154e+02  4.22e+02  8.86e-01  1.26e+01  1.00e+00  1.00e+00   ------
#   1  +1.6563e+02  -3.6742e-01  1.66e+02  2.62e-01  3.99e+00  5.73e-01  2.94e-01  7.28e-01
#   2  +1.3699e+02  +4.6079e+01  1.97e+00  1.56e-01  2.09e+00  2.78e-01  1.72e-01  5.57e-01
#   3  +1.2841e+02  +8.2480e+01  5.57e-01  8.14e-02  9.02e-01  1.37e-01  8.88e-02  5.54e-01
#   4  +1.2812e+02  +9.8253e+01  3.04e-01  5.54e-02  4.25e-01  9.29e-02  5.55e-02  5.37e-01
#   5  +1.3389e+02  +1.1626e+02  1.52e-01  3.43e-02  1.47e-01  6.16e-02  2.90e-02  6.07e-01
#   6  +1.3748e+02  +1.2729e+02  8.00e-02  2.02e-02  6.18e-02  3.83e-02  1.52e-02  5.00e-01
#   7  +1.3963e+02  +1.3723e+02  1.75e-02  4.80e-03  1.19e-02  8.57e-03  3.35e-03  9.90e-01
#   8  +1.3994e+02  +1.3939e+02  3.92e-03  1.10e-03  2.52e-03  1.99e-03  7.44e-04  7.92e-01
#   9  +1.4001e+02  +1.4000e+02  7.71e-05  2.17e-05  4.89e-05  4.14e-05  1.46e-05  9.90e-01
#  10  +1.4002e+02  +1.4001e+02  1.65e-05  4.65e-06  1.05e-05  8.89e-06  3.13e-06  7.92e-01
#  11  +1.4002e+02  +1.4002e+02  3.54e-06  9.97e-07  2.25e-06  1.91e-06  6.70e-07  7.92e-01
#  12  +1.4002e+02  +1.4002e+02  7.59e-07  2.14e-07  4.82e-07  4.10e-07  1.44e-07  7.92e-01
#  13  +1.4002e+02  +1.4002e+02  6.65e-07  1.87e-07  4.22e-07  3.62e-07  1.26e-07  2.08e-01
#  14  +1.4002e+02  +1.4002e+02  6.65e-07  1.87e-07  4.22e-07  3.62e-07  1.26e-07  0.00e+00
#  15  +1.4002e+02  +1.4002e+02  2.62e-07  7.38e-08  1.67e-07  1.43e-07  5.03e-08  6.34e-01
#  16  +1.4002e+02  +1.4002e+02  5.62e-08  1.58e-08  3.57e-08  3.07e-08  1.08e-08  7.92e-01
#  17  +1.4002e+02  +1.4002e+02  2.24e-08  6.30e-09  1.42e-08  1.24e-08  4.25e-09  6.34e-01
#  18  +1.4002e+02  +1.4002e+02  2.14e-08  6.03e-09  1.36e-08  1.18e-08  4.06e-09  4.35e-02
#  19  +1.4002e+02  +1.4002e+02  2.68e-09  7.56e-10  1.71e-09  1.58e-09  5.06e-10  9.90e-01
# ---------------------------------------------------------------------------------------------
# Terminated with status = Solved
# solve time = 9.296998ms
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# Text(0, 0.5, 'Mean viral load copies/L')

# %%
from scipy.linalg import toeplitz

# previously estimated kernel
S = x.value 

# viral load
VL = cdf['Mean viral gene copies/L'].values
VL = VL[F:(len(VL)-N+F)]

# K is a Toeplitz matrix representing convolution with S
first_col = np.r_[S[0], np.zeros(len(VL)-1)]
first_row = np.r_[S, np.zeros(len(VL) - len(S))]
K = toeplitz(first_col, first_row)

# solve for C in V = S * C
lambda_reg = 0.01
I = np.eye(K.shape[1])
C = np.linalg.solve(K.T @ K + lambda_reg * I, K.T @ VL)

# align time index for plotting
C_dates = cdf.index[F:(len(cdf.index)-N+F)]


plt.figure(figsize=(10, 5))
plt.plot(C_dates, C, label='Inferred Clinical Cases from Wastewater', linewidth=2)
plt.plot(C_dates, Y, label='Reported Clinical Cases', linewidth=2)
plt.legend()
plt.xlabel('Date')
plt.ylabel('Cases')
# Out:
# Text(0, 0.5, 'Cases')

# %%
# Lag analysis
lags = np.arange(-15, 16)
correlations = [np.corrcoef(Y[:len(C)], np.roll(C, lag))[0, 1] for lag in lags]
plt.figure()
plt.plot(lags, correlations)
plt.title("Lag vs. Correlation")
plt.xlabel("Lag (days)")
plt.ylabel("Correlation")
# Out:
# Text(0, 0.5, 'Correlation')

# %%
# changing lambda_reg
lambda_reg = 4000000
C = np.linalg.solve(K.T @ K + lambda_reg * I, K.T @ VL)

plt.figure(figsize=(10, 5))
plt.plot(C_dates, C, label='Inferred Clinical Cases from Wastewater', linewidth=2)
plt.plot(C_dates, Y, label='Reported Clinical Cases', linewidth=2)
plt.legend()
plt.xlabel('Date')
plt.ylabel('Cases')
# Out:
# Text(0, 0.5, 'Cases')

# %%
# Lag analysis
lags = np.arange(-15, 16)
correlations = [np.corrcoef(Y[:len(C)], np.roll(C, lag))[0, 1] for lag in lags]
plt.figure()
plt.plot(lags, correlations)
plt.title("Lag vs. Correlation")
plt.xlabel("Lag (days)")
plt.ylabel("Correlation")
# Out:
# Text(0, 0.5, 'Correlation')

# %%
# 1. Inverting the shedding kernel, then just using regular convolution

from scipy.signal import fftconvolve
import matplotlib.pyplot as plt

# previously estimated kernel
S = x.value 

# viral load
VL = cdf['Mean viral gene copies/L'].values
VL = VL[F:(len(VL)-N+F)]

# reverse the kernel (deconvolution)
S_flipped = S[::-1] / S.sum()

# perform convolution
C_conv = fftconvolve(VL, S_flipped, mode='valid')

# adjust time axis
C_dates_conv = C_dates[:len(C_conv)]

# Plot
plt.figure(figsize=(10, 5))
plt.plot(C_dates_conv, C_conv, label='Inferred Clinical Cases from Wastewater', linewidth=2)
plt.plot(C_dates_conv, Y[:len(C_conv)], label='Reported Clinical Cases', linewidth=2)
plt.legend()
plt.xlabel("Date")
plt.ylabel("Cases")
# Out:
# Text(0, 0.5, 'Cases')

# %%
# 2. Performing the linear solve with a nonnegativity constraint

import cvxpy as cp

# previously estimated kernel
S = x.value 

# viral load
VL = cdf['Mean viral gene copies/L'].values
VL = VL[F:(len(VL)-N+F)]

# K is a Toeplitz matrix representing convolution with S
first_col = np.r_[S[0], np.zeros(len(VL)-1)]
first_row = np.r_[S, np.zeros(len(VL) - len(S))]
K = toeplitz(first_col, first_row)

# solve
C = cp.Variable(K.shape[1])
cost = cp.norm(K @ C - VL, 2)
constraints = [C >= 0]
prob = cp.Problem(cp.Minimize(cost), constraints)
prob.solve(verbose=True)

C_nnls = C.value
C_dates_nnls = C_dates[:len(C_nnls)]


plt.figure(figsize=(10, 5))
plt.plot(C_dates_nnls, C_nnls, label='Inferred Clinical Cases from Wastewater', linewidth=2)
plt.plot(C_dates, Y[:len(C_nnls)], label='Reported Clinical Cases', linewidth=2)
plt.legend()
plt.ylim(-1000,40000)
plt.xlabel("Date")
plt.ylabel("Cases")
# Out:
# (CVXPY) Jul 08 02:08:59 PM: Your problem has 202 variables, 202 constraints, and 0 parameters.
# (CVXPY) Jul 08 02:09:00 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jul 08 02:09:00 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jul 08 02:09:00 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Jul 08 02:09:00 PM: Your problem is compiled with the CPP canonicalization backend.
# (CVXPY) Jul 08 02:09:00 PM: Compiling problem (target solver=CLARABEL).
# (CVXPY) Jul 08 02:09:00 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> CLARABEL
# (CVXPY) Jul 08 02:09:00 PM: Applying reduction Dcp2Cone
# (CVXPY) Jul 08 02:09:00 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jul 08 02:09:00 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Jul 08 02:09:00 PM: Applying reduction CLARABEL
# (CVXPY) Jul 08 02:09:00 PM: Finished problem compilation (took 8.631e-03 seconds).
# (CVXPY) Jul 08 02:09:00 PM: Invoking solver CLARABEL  to obtain a solution.
# ===============================================================================
#                                      CVXPY
#                                      v1.6.6
# ===============================================================================
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# -------------------------------------------------------------
#            Clarabel.rs v0.11.1  -  Clever Acronym
#
#                    (c) Paul Goulart
#                 University of Oxford, 2022
# -------------------------------------------------------------
#
# problem:
#   variables     = 203
#   constraints   = 405
#   nnz(P)        = 0
#   nnz(A)        = 5828
#   cones (total) = 2
#     : Nonnegative = 1,  numel = 202
#     : SecondOrder = 1,  numel = 203
#
# settings:
#   linear algebra: direct / qdldl, precision: 64 bit (1 thread)
#   max iter = 200, time limit = Inf,  max step = 0.990
#   tol_feas = 1.0e-8, tol_gap_abs = 1.0e-8, tol_gap_rel = 1.0e-8,
#   static reg : on, ϵ1 = 1.0e-8, ϵ2 = 4.9e-32
#   dynamic reg: on, ϵ = 1.0e-13, δ = 2.0e-7
#   iter refine: on, reltol = 1.0e-13, abstol = 1.0e-12,
#                max iter = 10, stop ratio = 5.0
#   equilibrate: on, min_scale = 1.0e-4, max_scale = 1.0e4
#                max iter = 10
#
# iter    pcost        dcost       gap       pres      dres      k/t        μ       step
# ---------------------------------------------------------------------------------------------
# (CVXPY) Jul 08 02:09:00 PM: Problem status: optimal
# (CVXPY) Jul 08 02:09:00 PM: Optimal value: 1.977e+07
# (CVXPY) Jul 08 02:09:00 PM: Compilation took 8.631e-03 seconds
# (CVXPY) Jul 08 02:09:00 PM: Solver (including time spent in interface) took 1.074e-02 seconds
#   0  +0.0000e+00  -0.0000e+00  0.00e+00  9.97e-01  3.73e-03  1.00e+00  6.67e+09   ------
#   1  +1.9128e+07  +1.9129e+07  6.14e-05  2.13e-01  2.02e-08  1.17e+03  1.09e+08  9.85e-01
#   2  +1.9455e+07  +2.0087e+07  3.25e-02  5.25e-02  4.42e-09  6.32e+05  2.50e+07  7.81e-01
#   3  +1.9459e+07  +1.9689e+07  1.18e-02  2.24e-02  3.26e-09  2.30e+05  2.35e+07  2.10e-01
#   4  +1.9437e+07  +1.9490e+07  2.70e-03  6.84e-03  1.14e-09  5.25e+04  1.07e+07  5.88e-01
#   5  +1.9483e+07  +1.9592e+07  5.61e-03  1.02e-02  1.39e-09  1.09e+05  8.80e+06  4.84e-01
#   6  +1.9581e+07  +1.9591e+07  5.02e-04  2.56e-03  5.44e-10  9.83e+03  3.22e+06  8.77e-01
#   7  +1.9578e+07  +1.9590e+07  6.33e-04  2.82e-03  5.24e-10  1.24e+04  2.67e+06  4.16e-01
#   8  +1.9664e+07  +1.9668e+07  1.71e-04  1.09e-03  2.33e-10  3.37e+03  1.34e+06  7.06e-01
#   9  +1.9717e+07  +1.9717e+07  3.67e-05  5.24e-04  1.10e-10  7.23e+02  6.04e+05  9.90e-01
#  10  +1.9760e+07  +1.9760e+07  6.39e-06  1.03e-04  3.38e-11  1.26e+02  1.33e+05  8.25e-01
#  11  +1.9767e+07  +1.9767e+07  2.94e-06  4.76e-05  1.61e-11  5.82e+01  6.20e+04  7.16e-01
#  12  +1.9771e+07  +1.9771e+07  7.42e-07  1.23e-05  2.42e-11  1.47e+01  1.68e+04  7.99e-01
#  13  +1.9773e+07  +1.9773e+07  7.34e-08  1.40e-06  3.75e-12  1.45e+00  1.96e+03  9.28e-01
#  14  +1.9773e+07  +1.9773e+07  2.61e-08  4.92e-07  2.19e-12  5.16e-01  6.92e+02  6.80e-01
#  15  +1.9773e+07  +1.9773e+07  5.20e-09  9.39e-08  8.17e-12  1.03e-01  1.32e+02  9.33e-01
#  16  +1.9773e+07  +1.9773e+07  4.13e-10  7.38e-09  7.96e-13  8.16e-03  1.03e+01  9.56e-01
# ---------------------------------------------------------------------------------------------
# Terminated with status = Solved
# solve time = 8.403083ms
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# Text(0, 0.5, 'Cases')
